# %%
from osgeo import gdal, ogr, osr

# Define the paths to your rasters
lidarHAG_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\lidarHAG\LIDAR_GEDI_CO.tif"
pcl_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_3.tif"

# Open the source (lidarHAG) and target (pcl) datasets
src_ds = gdal.Open(lidarHAG_path, gdal.GA_ReadOnly)
target_ds = gdal.Open(pcl_path, gdal.GA_ReadOnly)


# Get the Geotransform and Projection from the target dataset
target_transform = target_ds.GetGeoTransform()
target_projection = target_ds.GetProjection()
target_cols = target_ds.RasterXSize
target_rows = target_ds.RasterYSize

# Create a new dataset for output with the same size and projection as the target
driver = gdal.GetDriverByName('GTiff')
output_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO_11.tif"
out_ds = driver.Create(output_path, target_cols, target_rows, 1, src_ds.GetRasterBand(1).DataType)
out_ds.SetGeoTransform(target_transform)
out_ds.SetProjection(target_projection)

# Perform the resampling
gdal.ReprojectImage(src_ds, out_ds, src_ds.GetProjection(), target_projection, gdal.GRA_Bilinear)

# Close the datasets
src_ds = None
target_ds = None
out_ds = None

print("Resampling completed. Output saved at:", output_path)

# Define the paths to your rasters
lidarHAG_path = output_path

# Open the datasets
lidarHAG_ds = gdal.Open(lidarHAG_path, gdal.GA_ReadOnly)
pcl_ds = gdal.Open(pcl_path, gdal.GA_ReadOnly)

# Function to extract raster details
def get_raster_details(dataset):
    geotransform = dataset.GetGeoTransform()
    projection = dataset.GetProjection()
    cols = dataset.RasterXSize
    rows = dataset.RasterYSize
    pixel_width = geotransform[1]
    pixel_height = geotransform[5]
    
    return {
        "cols": cols,
        "rows": rows,
        "pixel_width": pixel_width,
        "pixel_height": pixel_height,
        "projection": projection
    }

# Get details for both datasets
lidarHAG_details = get_raster_details(lidarHAG_ds)
pcl_details = get_raster_details(pcl_ds)

# Print the details
print("LIDAR HAG Raster Details:")
print("Columns:", lidarHAG_details['cols'])
print("Rows:", lidarHAG_details['rows'])
print("Pixel Width:", lidarHAG_details['pixel_width'])
print("Pixel Height:", lidarHAG_details['pixel_height'])
print("Projection:", lidarHAG_details['projection'])

print("\nPCL Raster Details:")
print("Columns:", pcl_details['cols'])
print("Rows:", pcl_details['rows'])
print("Pixel Width:", pcl_details['pixel_width'])
print("Pixel Height:", pcl_details['pixel_height'])
print("Projection:", pcl_details['projection'])

# Close datasets
lidarHAG_ds = None
pcl_ds = None
print("DONE!!!")

# %%
# from osgeo import gdal

# def resize_tif(input_tif, output_tif, target_width, target_height):
#     # Open the input GeoTIFF
#     src_ds = gdal.Open(input_tif)

#     # Get the original size
#     src_width = src_ds.RasterXSize
#     src_height = src_ds.RasterYSize

#     # Calculate scaling factors
#     x_scale = target_width / src_width
#     y_scale = target_height / src_height

#     # Set the new size
#     dst_width = target_width
#     dst_height = target_height

#     # Create the output GeoTIFF
#     driver = gdal.GetDriverByName('GTiff')
#     dst_ds = driver.Create(output_tif, dst_width, dst_height,
#                            src_ds.RasterCount, src_ds.GetRasterBand(1).DataType)

#     # Apply the scaling transformation
#     dst_ds.SetGeoTransform((src_ds.GetGeoTransform()[0],
#                             x_scale,
#                             0,
#                             src_ds.GetGeoTransform()[3],
#                             0,
#                             y_scale))

#     # Perform the resizing
#     gdal.ReprojectImage(src_ds, dst_ds, None, None, gdal.GRA_Bilinear)

#     # Close the datasets
#     src_ds = None
#     dst_ds = None

# # Example usage
# input_tif_large = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO5.tif"
# input_tif_small = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_2.tif"
# output_tif_resized = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO5_CLIPPED.tif"

# # Get the dimensions of the smaller GeoTIFF
# src_ds_small = gdal.Open(input_tif_small)
# target_width = src_ds_small.RasterXSize
# target_height = src_ds_small.RasterYSize
# src_ds_small = None

# # Resize the larger GeoTIFF to match the dimensions of the smaller one
# resize_tif(input_tif_large, output_tif_resized, target_width, target_height)

# %%
# from osgeo import gdal, ogr, osr

# # Define the paths to your rasters
# lidarHAG_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\lidarHAG\LIDAR_GEDI_CO.tif"
# pcl_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_2.tif"

# # Open the source (lidarHAG) and target (pcl) datasets
# src_ds = gdal.Open(lidarHAG_path, gdal.GA_ReadOnly)
# target_ds = gdal.Open(pcl_path, gdal.GA_ReadOnly)

# # Get the Geotransform, Projection, and size from the target dataset
# target_transform = target_ds.GetGeoTransform()
# target_projection = target_ds.GetProjection()
# target_cols = target_ds.RasterXSize
# target_rows = target_ds.RasterYSize

# # Create a new dataset for output with the same size, projection, and geotransform as the target
# driver = gdal.GetDriverByName('GTiff')
# output_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO.tif"
# out_ds = driver.Create(output_path, target_cols, target_rows, 1, src_ds.GetRasterBand(1).DataType)
# out_ds.SetGeoTransform(target_transform)
# out_ds.SetProjection(target_projection)

# # Set up the reprojection with clipping
# gdal.ReprojectImage(src_ds, out_ds, src_ds.GetProjection(), target_projection, gdal.GRA_Bilinear)

# # Flush changes and close datasets
# out_ds.FlushCache()
# src_ds = None
# target_ds = None
# out_ds = None

# print("Resampling and clipping completed. Output saved at:", output_path)

# %%
# from osgeo import gdal

# # Source and target datasets
# src_file = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\lidarHAG\LIDAR_GEDI_CO.tif"
# tgt_file = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_2.tif"
# output_file = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO2.tif"

# # Open target dataset to get the geotransform and projection
# tgt_ds = gdal.Open(tgt_file, gdal.GA_ReadOnly)
# tgt_geotransform = tgt_ds.GetGeoTransform()
# tgt_projection = tgt_ds.GetProjection()
# tgt_x_size = tgt_ds.RasterXSize
# tgt_y_size = tgt_ds.RasterYSize

# # Calculate the output bounds using the target dataset's geotransform
# minX = tgt_geotransform[0]
# maxX = tgt_geotransform[0] + tgt_geotransform[1] * tgt_x_size
# minY = tgt_geotransform[3] + tgt_geotransform[5] * tgt_y_size
# maxY = tgt_geotransform[3]

# # Close the target dataset
# tgt_ds = None

# # Reproject and clip
# warp_options = gdal.WarpOptions(format='GTiff',
#                                 outputBounds=(minX, minY, maxX, maxY),
#                                 xRes=tgt_geotransform[1],
#                                 yRes=abs(tgt_geotransform[5]),
#                                 dstSRS=tgt_projection,
#                                 resampleAlg=gdal.GRA_Bilinear,
#                                 targetAlignedPixels=True)

# gdal.Warp(destNameOrDestDS=output_file, srcDSOrSrcDSTab=src_file, options=warp_options)

# print("Resampling and explicit clipping completed. Output saved at:", output_file)

# %%
# from osgeo import gdal, gdal_array

# # Define the paths to your rasters
# lidarHAG_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\lidarHAG\LIDAR_GEDI_CO.tif"
# pcl_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_2.tif"

# # Open the source (lidarHAG) and target (pcl) datasets
# src_ds = gdal.Open(lidarHAG_path, gdal.GA_ReadOnly)
# target_ds = gdal.Open(pcl_path, gdal.GA_ReadOnly)

# # Get the Geotransform and Projection from the target dataset
# target_transform = target_ds.GetGeoTransform()
# target_projection = target_ds.GetProjection()
# target_cols = target_ds.RasterXSize
# target_rows = target_ds.RasterYSize
# nodata_value = -9999

# # Create a new dataset for output with the same size and projection as the target
# driver = gdal.GetDriverByName('GTiff')
# output_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO4.tif"
# out_ds = driver.Create(output_path, target_cols, target_rows, 1, src_ds.GetRasterBand(1).DataType)
# out_ds.SetGeoTransform(target_transform)
# out_ds.SetProjection(target_projection)

# # Perform the resampling
# gdal.ReprojectImage(src_ds, out_ds, src_ds.GetProjection(), target_projection, gdal.GRA_Bilinear)

# # Read the mask raster (pcl_path) into an array
# mask_band = target_ds.GetRasterBand(1)
# mask_array = mask_band.ReadAsArray()

# # Convert the mask to a binary mask (assuming that valid mask values are non-zero)
# numpy_dtype = gdal_array.GDALTypeCodeToNumericTypeCode(mask_band.DataType)
# binary_mask = (mask_array > 0).astype(numpy_dtype)

# # Read the reprojected data into an array
# reprojected_array = out_ds.GetRasterBand(1).ReadAsArray()

# # Apply the mask to the reprojected data
# reprojected_array *= binary_mask
# reprojected_array[binary_mask == 0] = nodata_value

# # Write the masked data back to the output dataset
# out_ds.GetRasterBand(1).WriteArray(reprojected_array)
# out_ds.GetRasterBand(1).SetNoDataValue(nodata_value)

# # Flush changes to disk and close datasets
# out_ds.FlushCache()
# src_ds = None
# target_ds = None
# out_ds = None

# print("Reprojected and masked raster saved to:", output_path)

# %%
# THIS MAKES A LIST OF LAT LONG
import rasterio
from rasterio.features import geometry_mask
from shapely.geometry import Point, box
from geopandas import GeoDataFrame
import numpy as np

# Load the GeoTIFF file
file_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_3.tif"
with rasterio.open(file_path) as src:
    # Extract the bounds of the raster
    bounds = src.bounds
    crs = src.crs

# Create a box from the bounds
rect = box(bounds.left, bounds.bottom, bounds.right, bounds.top)

# Apply a negative buffer to contract the boundary of the rectangle
buffered_rect = rect.buffer(-0.00001)  # Change 1000 to your desired buffer distance in units of the CRS

# Check if the buffered rectangle is empty (can happen with large negative buffers)
if buffered_rect.is_empty:
    raise ValueError("Buffer size is too large")

# Function to generate random points within a geometry
def generate_random_points(geometry, num_points):
    points = []
    min_x, min_y, max_x, max_y = geometry.bounds
    while len(points) < num_points:
        random_point = Point(np.random.uniform(min_x, max_x), np.random.uniform(min_y, max_y))
        if random_point.within(geometry):
            points.append(random_point)
    return points

# Generate random points within the buffered rectangle
random_points = generate_random_points(buffered_rect, 2000)

# Convert these points to a GeoDataFrame
gdf_points = GeoDataFrame(geometry=random_points, crs=crs)

# Convert geometries from the CRS to WGS84 for latitude and longitude
gdf_points_wgs84 = gdf_points.to_crs(epsg=4326)

# Extract the latitude and longitude
lat_long = gdf_points_wgs84.geometry.apply(lambda geom: (geom.y, geom.x)).tolist()

# # Print the latitude and longitude coordinates
# for lat, lon in lat_long:
#     print(f"Latitude: {lat}, Longitude: {lon}")
print("done")
# Out:
# done

# %%
import rasterio
from rasterio.windows import Window

# Paths to the raster file
resampled_PCL_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_3.tif"
resampled_lidar_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO_11.tif"

# Size of the chip around the point (in pixels)
chip_size = 100  # creates a 200x200 pixels chip (100 pixels on each side of the point)

for i in range(len(random_points)):
    try:
        # Define the coordinates of the point (replace these with your actual coordinates)
        x_coord = lat_long[i][1] 
        y_coord = lat_long[i][0] 
        
        # Open the resampled LIDAR raster
        with rasterio.open(resampled_PCL_path) as lidar:
            # Convert the geographic coordinates to pixel coordinates
            col, row = lidar.index(x_coord, y_coord)
            
            # Calculate the window
            window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
            
            # Read the data within the window
            chip_data = lidar.read(window=window)
            
            # Prepare metadata for the chip raster
            out_meta = lidar.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": chip_data.shape[1],
                "width": chip_data.shape[2],
                "transform": lidar.window_transform(window)
            })
        
            # Save the chip data to a new file
            chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO\\labels\\PCL_Chip_{i}.tif"
            #with rasterio.open(chip_output_path, "w", **out_meta) as dest:
            #    dest.write(chip_data)
            try:
                if chip_data.shape == (1,200,200) and not np.allclose(chip_data, 0):
                    with rasterio.open(chip_output_path, "w", **out_meta) as dest:
                        dest.write(chip_data)
                else:
                    print(f"Skipping chip {i} because its shape is not 200x200.")
            except Exception as e:
                print(f"Error occurred while saving chip {i}: {e}")
        
        print("Image chip created and saved to:", chip_output_path)
        
        # Open the resampled LIDAR raster
        with rasterio.open(resampled_lidar_path) as lidar:
            # Convert the geographic coordinates to pixel coordinates
            col, row = lidar.index(x_coord, y_coord)
            
            # Calculate the window
            window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
            
            # Read the data within the window
            chip_data = lidar.read(window=window)
            
            # Prepare metadata for the chip raster
            out_meta = lidar.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": chip_data.shape[1],
                "width": chip_data.shape[2],
                "transform": lidar.window_transform(window)
            })
        
            # Save the chip data to a new file
            chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO\\inputfeatures\\LIDAR_Chip_{i}.tif"
            #with rasterio.open(chip_output_path, "w", **out_meta) as dest:
            #    dest.write(chip_data)
            try:
                if chip_data.shape == (1,200,200) and not np.isnan(chip_data).all():
                    with rasterio.open(chip_output_path, "w", **out_meta) as dest:
                        dest.write(chip_data)
                else:
                    print(f"Skipping chip {i} because its shape is not 200x200.")
            except Exception as e:
                print(f"Error occurred while saving chip {i}: {e}")
        
        
        print("Image chip created and saved to:", chip_output_path)
    except:
        continue
# Out:
# Skipping chip 0 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_0.tif
# Skipping chip 0 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_0.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_2.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_2.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_3.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_3.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_4.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_4.tif
# Skipping chip 5 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_5.tif
# Skipping chip 5 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_5.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_6.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_6.tif
# Skipping chip 7 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_7.tif
# Skipping chip 7 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_7.tif
# Skipping chip 8 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_8.tif
# Skipping chip 8 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_8.tif
# Skipping chip 9 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_9.tif
# Skipping chip 9 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_9.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_10.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_10.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_11.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_11.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_12.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_12.tif
# Skipping chip 13 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_13.tif
# Skipping chip 13 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_13.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_14.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_14.tif
# Skipping chip 15 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_15.tif
# Skipping chip 15 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_15.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_16.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_16.tif
# Skipping chip 17 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_17.tif
# Skipping chip 17 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_17.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_18.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_18.tif
# Skipping chip 19 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_19.tif
# Skipping chip 19 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_19.tif
# Skipping chip 20 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_20.tif
# Skipping chip 20 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_20.tif
# Skipping chip 21 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_21.tif
# Skipping chip 21 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_21.tif
# Skipping chip 22 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_22.tif
# Skipping chip 22 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_22.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_23.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_23.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_24.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_24.tif
# Skipping chip 25 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_25.tif
# Skipping chip 25 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_25.tif
# Skipping chip 26 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_26.tif
# Skipping chip 26 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_26.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_27.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_27.tif
# Skipping chip 28 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_28.tif
# Skipping chip 28 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_28.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_29.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_29.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_30.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_30.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_31.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_31.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_32.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_32.tif
# Skipping chip 33 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_33.tif
# Skipping chip 33 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_33.tif
# Skipping chip 34 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_34.tif
# Skipping chip 34 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_34.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_35.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_35.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_36.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_36.tif
# Skipping chip 37 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_37.tif
# Skipping chip 37 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_37.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_38.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_38.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_39.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_39.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_40.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_40.tif
# Skipping chip 41 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_41.tif
# Skipping chip 41 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_41.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_42.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_42.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_43.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_43.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_44.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_44.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_45.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_45.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_46.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_46.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_47.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_47.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_48.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_48.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_49.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_49.tif
# Skipping chip 50 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_50.tif
# Skipping chip 50 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_50.tif
# Skipping chip 51 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_51.tif
# Skipping chip 51 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_51.tif
# Skipping chip 52 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_52.tif
# Skipping chip 52 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_52.tif
# Skipping chip 53 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_53.tif
# Skipping chip 53 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_53.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_54.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_54.tif
# Skipping chip 55 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_55.tif
# Skipping chip 55 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_55.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_56.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_56.tif
# Skipping chip 57 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_57.tif
# Skipping chip 57 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_57.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_58.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_58.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_59.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_59.tif
# Skipping chip 60 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_60.tif
# Skipping chip 60 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_60.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_61.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_61.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_62.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_62.tif
# Skipping chip 63 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_63.tif
# Skipping chip 63 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_63.tif
# Skipping chip 64 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_64.tif
# Skipping chip 64 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_64.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_65.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_65.tif
# Skipping chip 66 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_66.tif
# Skipping chip 66 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_66.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_67.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_67.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_68.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_68.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_69.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_69.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_70.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_70.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_71.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_71.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_72.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_72.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_73.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_73.tif
# Skipping chip 74 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_74.tif
# Skipping chip 74 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_74.tif
# Skipping chip 75 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_75.tif
# Skipping chip 75 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_75.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_76.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_76.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_77.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_77.tif
# Skipping chip 78 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_78.tif
# Skipping chip 78 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_78.tif
# Skipping chip 79 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_79.tif
# Skipping chip 79 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_79.tif
# Skipping chip 80 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_80.tif
# Skipping chip 80 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_80.tif
# Skipping chip 81 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_81.tif
# Skipping chip 81 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_81.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_82.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_82.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_83.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_83.tif
# Skipping chip 84 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_84.tif
# Skipping chip 84 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_84.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_85.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_85.tif
# Skipping chip 86 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_86.tif
# Skipping chip 86 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_86.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_87.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_87.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_88.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_88.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_89.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_89.tif
# Skipping chip 90 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_90.tif
# Skipping chip 90 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_90.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_91.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_91.tif
# Skipping chip 92 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_92.tif
# Skipping chip 92 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_92.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_93.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_93.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_94.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_94.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_95.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_95.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_96.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_96.tif
# Skipping chip 97 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_97.tif
# Skipping chip 97 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_97.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_98.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_98.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_99.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_99.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_100.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_100.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_101.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_101.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_102.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_102.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_103.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_103.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_104.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_104.tif
# Skipping chip 105 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_105.tif
# Skipping chip 105 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_105.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_106.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_106.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_107.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_107.tif
# Skipping chip 108 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_108.tif
# Skipping chip 108 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_108.tif
# Skipping chip 109 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_109.tif
# Skipping chip 109 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_109.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_110.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_110.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_111.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_111.tif
# Skipping chip 112 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_112.tif
# Skipping chip 112 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_112.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_113.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_113.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_114.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_114.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_115.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_115.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_116.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_116.tif
# Skipping chip 117 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_117.tif
# Skipping chip 117 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_117.tif
# Skipping chip 118 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_118.tif
# Skipping chip 118 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_118.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_119.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_119.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_120.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_120.tif
# Skipping chip 121 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_121.tif
# Skipping chip 121 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_121.tif
# Skipping chip 122 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_122.tif
# Skipping chip 122 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_122.tif
# Skipping chip 123 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_123.tif
# Skipping chip 123 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_123.tif
# Skipping chip 124 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_124.tif
# Skipping chip 124 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_124.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_125.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_125.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_126.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_126.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_127.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_127.tif
# Skipping chip 128 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_128.tif
# Skipping chip 128 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_128.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_129.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_129.tif
# Skipping chip 130 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_130.tif
# Skipping chip 130 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_130.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_131.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_131.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_132.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_132.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_133.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_133.tif
# Skipping chip 134 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_134.tif
# Skipping chip 134 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_134.tif
# Skipping chip 135 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_135.tif
# Skipping chip 135 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_135.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_136.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_136.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_137.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_137.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_138.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_138.tif
# Skipping chip 139 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_139.tif
# Skipping chip 139 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_139.tif
# Skipping chip 140 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_140.tif
# Skipping chip 140 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_140.tif
# Skipping chip 141 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_141.tif
# Skipping chip 141 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_141.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_142.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_142.tif
# Skipping chip 143 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_143.tif
# Skipping chip 143 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_143.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_144.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_144.tif
# Skipping chip 145 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_145.tif
# Skipping chip 145 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_145.tif
# Skipping chip 146 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_146.tif
# Skipping chip 146 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_146.tif
# Skipping chip 147 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_147.tif
# Skipping chip 147 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_147.tif
# Skipping chip 148 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_148.tif
# Skipping chip 148 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_148.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_149.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_149.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_150.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_150.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_151.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_151.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_152.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_152.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_153.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_153.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_154.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_154.tif
# Skipping chip 155 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_155.tif
# Skipping chip 155 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_155.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_156.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_156.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_157.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_157.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_158.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_158.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_159.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_159.tif
# Skipping chip 160 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_160.tif
# Skipping chip 160 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_160.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_161.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_161.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_162.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_162.tif
# Skipping chip 163 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_163.tif
# Skipping chip 163 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_163.tif
# Skipping chip 164 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_164.tif
# Skipping chip 164 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_164.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_165.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_165.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_166.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_166.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_167.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_167.tif
# Skipping chip 168 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_168.tif
# Skipping chip 168 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_168.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_169.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_169.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_170.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_170.tif
# Skipping chip 171 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_171.tif
# Skipping chip 171 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_171.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_172.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_172.tif
# Skipping chip 173 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_173.tif
# Skipping chip 173 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_173.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_174.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_174.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_175.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_175.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_176.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_176.tif
# Skipping chip 177 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_177.tif
# Skipping chip 177 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_177.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_178.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_178.tif
# ...
# Skipping chip 1939 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1939.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1940.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1940.tif
# Skipping chip 1941 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1941.tif
# Skipping chip 1941 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1941.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1942.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1942.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1943.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1943.tif
# Skipping chip 1944 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1944.tif
# Skipping chip 1944 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1944.tif
# Skipping chip 1945 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1945.tif
# Skipping chip 1945 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1945.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1946.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1946.tif
# Skipping chip 1947 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1947.tif
# Skipping chip 1947 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1947.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1948.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1948.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1949.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1949.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1950.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1950.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1951.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1951.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1952.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1952.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1953.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1953.tif
# Skipping chip 1954 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1954.tif
# Skipping chip 1954 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1954.tif
# Skipping chip 1955 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1955.tif
# Skipping chip 1955 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1955.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1956.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1956.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1957.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1957.tif
# Skipping chip 1958 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1958.tif
# Skipping chip 1958 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1958.tif
# Skipping chip 1959 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1959.tif
# Skipping chip 1959 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1959.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1960.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1960.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1961.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1961.tif
# Skipping chip 1962 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1962.tif
# Skipping chip 1962 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1962.tif
# Skipping chip 1963 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1963.tif
# Skipping chip 1963 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1963.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1964.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1964.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1965.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1965.tif
# Skipping chip 1966 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1966.tif
# Skipping chip 1966 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1966.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1967.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1967.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1968.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1968.tif
# Skipping chip 1969 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1969.tif
# Skipping chip 1969 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1969.tif
# Skipping chip 1970 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1970.tif
# Skipping chip 1970 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1970.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1971.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1971.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1972.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1972.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1973.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1973.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1974.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1974.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1975.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1975.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1976.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1976.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1977.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1977.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1978.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1978.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1979.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1979.tif
# Skipping chip 1980 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1980.tif
# Skipping chip 1980 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1980.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1981.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1981.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1982.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1982.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1983.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1983.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1984.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1984.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1985.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1985.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1986.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1986.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1987.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1987.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1988.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1988.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1989.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1989.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1990.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1990.tif
# Skipping chip 1991 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1991.tif
# Skipping chip 1991 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1991.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1992.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1992.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1993.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1993.tif
# Skipping chip 1994 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1994.tif
# Skipping chip 1994 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1994.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1995.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1995.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1996.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1996.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1997.tif
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1997.tif
# Skipping chip 1998 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1998.tif
# Skipping chip 1998 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1998.tif
# Skipping chip 1999 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels\PCL_Chip_1999.tif
# Skipping chip 1999 because its shape is not 200x200.
# Image chip created and saved to: C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures\LIDAR_Chip_1999.tif

# %%
# # this is old not good 
# import rasterio
# from rasterio.windows import Window

# # Paths to the raster file
# resampled_PCL_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_3.tif"
# resampled_lidar_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\Input\Resampled_LIDAR_GEDI_CO_11.tif"

# # Size of the chip around the point (in pixels)
# chip_size = 100  # creates a 200x200 pixels chip (100 pixels on each side of the point)

# for i in range(len(random_points)):
#     try:
#         # Define the coordinates of the point (replace these with your actual coordinates)
#         x_coord = lat_long[i][1] 
#         y_coord = lat_long[i][0] 
        
#         # Open the resampled LIDAR raster
#         with rasterio.open(resampled_PCL_path) as lidar:
#             # Convert the geographic coordinates to pixel coordinates
#             col, row = lidar.index(x_coord, y_coord)
            
#             # Calculate the window
#             window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
            
#             # Read the data within the window
#             chip_data = lidar.read(window=window)
            
#             # Prepare metadata for the chip raster
#             out_meta = lidar.meta.copy()
#             out_meta.update({
#                 "driver": "GTiff",
#                 "height": chip_data.shape[1],
#                 "width": chip_data.shape[2],
#                 "transform": lidar.window_transform(window)
#             })
        
#             # Save the chip data to a new file
#             chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO\\labels\\PCL_Chip_{i}.tif"
#             #with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#             #    dest.write(chip_data)
#             try:
#                 if chip_data.shape == (1,200,200) and not np.allclose(chip_data, 0):
#                     with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#                         dest.write(chip_data)

#                     print("Image chip created and saved to:", chip_output_path)
        
#                     # Open the resampled LIDAR raster
#                     with rasterio.open(resampled_lidar_path) as lidar:
#                         # Convert the geographic coordinates to pixel coordinates
#                         col, row = lidar.index(x_coord, y_coord)
                        
#                         # Calculate the window
#                         window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
                        
#                         # Read the data within the window
#                         chip_data = lidar.read(window=window)
                        
#                         # Prepare metadata for the chip raster
#                         out_meta = lidar.meta.copy()
#                         out_meta.update({
#                             "driver": "GTiff",
#                             "height": chip_data.shape[1],
#                             "width": chip_data.shape[2],
#                             "transform": lidar.window_transform(window)
#                         })
                    
#                         # Save the chip data to a new file
#                         chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO\\inputfeatures\\LIDAR_Chip_{i}.tif"
#                         #with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#                         #    dest.write(chip_data)
#                         try:
#                             if chip_data.shape == (1,200,200) and not np.isnan(chip_data).all():
#                                 with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#                                     dest.write(chip_data)
#                             else:
#                                 print(f"Skipping chip {i} because its shape is not 200x200.")
#                         except Exception as e:
#                             print(f"Error occurred while saving chip {i}: {e}")
                    
                    
#                     print("Image chip created and saved to:", chip_output_path)
                
#                 else:
#                     print(f"Skipping chip {i} because its shape is not 200x200.")
#             except Exception as e:
#                 print(f"Error occurred while saving chip {i}: {e}")

# %%
# # THIS IS FOR ONE and works !

# import rasterio
# from rasterio.windows import Window

# # Paths to the raster file
# resampled_PCL_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\Input\pcl_west_wgs_CO_2.tif"

# # Paths to the raster file
# resampled_lidar_path = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\lidarHAG\Resampled_LIDAR_GEDI_CO.tif"

# # Define the coordinates of the point (replace these with your actual coordinates)
# x_coord = -106.94
# y_coord =  38.84

# # Size of the chip around the point (in pixels)
# chip_size = 100  # creates a 200x200 pixels chip (100 pixels on each side of the point)

# # Open the resampled LIDAR raster
# with rasterio.open(resampled_PCL_path) as lidar:
#     # Convert the geographic coordinates to pixel coordinates
#     col, row = lidar.index(x_coord, y_coord)
    
#     # Calculate the window
#     window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
    
#     # Read the data within the window
#     chip_data = lidar.read(window=window)
    
#     # Prepare metadata for the chip raster
#     out_meta = lidar.meta.copy()
#     out_meta.update({
#         "driver": "GTiff",
#         "height": chip_data.shape[1],
#         "width": chip_data.shape[2],
#         "transform": lidar.window_transform(window)
#     })

#     # Save the chip data to a new file
#     chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO1\\labels\\PCL_Chip_{i}.tif"
#     with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#         dest.write(chip_data)

# print("Image chip created and saved to:", chip_output_path)

# # Open the resampled LIDAR raster
# with rasterio.open(resampled_lidar_path) as lidar:
#     # Convert the geographic coordinates to pixel coordinates
#     col, row = lidar.index(x_coord, y_coord)
    
#     # Calculate the window
#     window = Window(col - chip_size, row - chip_size, 2 * chip_size, 2 * chip_size)
    
#     # Read the data within the window
#     chip_data = lidar.read(window=window)
    
#     # Prepare metadata for the chip raster
#     out_meta = lidar.meta.copy()
#     out_meta.update({
#         "driver": "GTiff",
#         "height": chip_data.shape[1],
#         "width": chip_data.shape[2],
#         "transform": lidar.window_transform(window)
#     })

#     # Save the chip data to a new file
#     chip_output_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO1\\inputfeatures\\LIDAR_Chip_{i}.tif"
#     with rasterio.open(chip_output_path, "w", **out_meta) as dest:
#         dest.write(chip_data)

# print("Image chip created and saved to:", chip_output_path)

# %%
import os
import rasterio
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define paths to the datasets
featurepath = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures"
labelspath = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels"

# Function to load GeoTIFF images as numpy arrays
def load_geotiff(path):
    with rasterio.open(path) as src:
        return src.read(1)  

# Load datasets
feature_images = [load_geotiff(os.path.join(featurepath, f)) for f in os.listdir(featurepath) if f.endswith('.tif')]
label_images = [load_geotiff(os.path.join(labelspath, f)) for f in os.listdir(labelspath) if f.endswith('.tif')]

# Convert lists to numpy arrays
feature_images = np.array(feature_images).astype('float32') / 100
label_images = np.array(label_images).astype('float32') / 100

# Expand dimensions to fit the model input shape (batch, height, width, channels)
feature_images = np.expand_dims(feature_images, axis=-1)
label_images = np.expand_dims(label_images, axis=-1)

# Define the CNN model
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(200, 200, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(1024, activation='relu'),
    Dense(200 * 200, activation='sigmoid'),  # Assuming the task is similar to regression
    tf.keras.layers.Reshape((200, 200, 1))
])

# Compile the model
model.compile(optimizer='adam', loss='mse')  # Mean squared error for a regression-like task

# Train the model
model.fit(feature_images, label_images, batch_size=64, epochs=2, validation_split=0.1)

# %%
import os
import rasterio
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Paths to datasets
featurepath = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\inputfeatures"
labelspath = r"C:\Users\smdur\OneDrive\Desktop\GLOBALPCL\CNNPCLDEMO\labels"

# Function to load GeoTIFF images as numpy arrays
def load_geotiff(path):
    with rasterio.open(path) as src:
        return src.read(1)

# Load datasets
feature_images = [load_geotiff(os.path.join(featurepath, f)) for f in os.listdir(featurepath) if f.endswith('.tif')]
label_images = [load_geotiff(os.path.join(labelspath, f)) for f in os.listdir(labelspath) if f.endswith('.tif')]

# Convert lists to numpy arrays
feature_images = np.array(feature_images).astype('float32')
label_images = np.array(label_images).astype('float32')

# Determine maximum value in feature images to normalize correctly
feature_max = feature_images.max()
print(feature_max)
# Normalize to the range [0, 1]
feature_images /= feature_max
label_images /= 100  # Assuming label images range from 0 to 100

# Reshape for CNN input
feature_images = np.expand_dims(feature_images, axis=-1)
label_images = np.expand_dims(label_images, axis=-1)

# Define the CNN model
# model = Sequential([
#     Conv2D(16, (3, 3), activation='relu', input_shape=(200, 200, 1)),
#     MaxPooling2D((2, 2)),
#     Conv2D(32, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     Flatten(),
#     Dense(1024, activation='relu'),
#     Dense(200 * 200, activation='sigmoid'),  # Assuming regression-like task
#     tf.keras.layers.Reshape((200, 200, 1))
# ])


model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(200, 200, 1)),
    MaxPooling2D((2, 2)),
    Dropout(0.25),  # Dropout 25% of the nodes
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),  # Dropout 25% of the nodes
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dropout(0.5),  # Higher dropout for fully connected layer
    Dense(1024, activation='relu'),
    Dense(200 * 200, activation='sigmoid'),  # Assuming regression-like task
    tf.keras.layers.Reshape((200, 200, 1))
])



# Compile the model
model.compile(optimizer='adam', loss='mse')  # Mean squared error for a regression-like task

# Train the model
model.fit(feature_images, label_images, batch_size=64, epochs=2, validation_split=0.1)
# Out:
# 36.0
# Epoch 1/2
# 18/18 [==============================] - 18s 936ms/step - loss: 0.0886 - val_loss: 0.0774
# Epoch 2/2
# 18/18 [==============================] - 17s 922ms/step - loss: 0.0547 - val_loss: 0.0564

# %%
# this ensures all tiles are widthtile by heighttile
import os
from itertools import product
import rasterio as rio
from rasterio import windows

in_path = 'C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\CNNPCLDEMO\\Input\\'
input_filename = 'Resampled_LIDAR_GEDI_CO_11.tif'
out_path = 'C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\HAGTiles\\'
output_filename = 'tile_{}-{}.tif'
widthtile = 200
heighttile = 200

def get_tiles(ds, width=widthtile, height=heighttile):
    nols, nrows = ds.meta['width'], ds.meta['height']
    #offsets = product(range(0, nols, width), range(0, nrows, height))
    offsets = product(range(0, nols, 10), range(0, nrows, 10))

    big_window = windows.Window(col_off=0, row_off=0, width=nols, height=nrows)
    for col_off, row_off in offsets:
        window = windows.Window(col_off=col_off, row_off=row_off, width=width, height=height).intersection(big_window)
        transform = windows.transform(window, ds.transform)
        yield window, transform

with rio.open(os.path.join(in_path, input_filename)) as inds:
    tile_width, tile_height = widthtile, heighttile
    nodata = inds.nodata  # Get the NoData value from the dataset
    meta = inds.meta.copy()

    for window, transform in get_tiles(inds):
        if window.width == tile_width and window.height == tile_height:  # Check if the tile dimensions are as expected
            data = inds.read(window=window)
            if nodata is not None:
                # Modified check for NoData to include tolerance for floating-point rasters
                valid_data_mask = (data != nodata)
            else:
                # If NoData value is not set, consider all data as valid
                valid_data_mask = (data == data)

            if valid_data_mask.any():  # Check if there's any valid data within the tile
                meta['transform'] = transform
                meta['width'], meta['height'] = window.width, window.height
                outpath = os.path.join(out_path, output_filename.format(int(window.col_off), int(window.row_off)))
                with rio.open(outpath, 'w', **meta) as outds:
                    outds.write(data)

print("Done")

# %%
feature_max
# Out:
# 36.0

# %%
import os
import rasterio
import numpy as np
import tensorflow as tf

tilename = '20-3800'

# Path to the new image
input_image_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\HAGTiles\\tile_{tilename}.tif"

# Function to load and preprocess the image
def load_and_preprocess_image(path):
    with rasterio.open(path) as src:
        image = src.read(1)  # Read the first band
    image = np.array(image).astype('float32') / feature_max  # Normalize the pixel values based on the model above
    image = np.expand_dims(image, axis=-1)  # Add a channel dimension
    image = np.expand_dims(image, axis=0)  # Add a batch dimension
    return image

# Load and preprocess the input image
input_image = load_and_preprocess_image(input_image_path)

# Predict using the trained model
predicted_image = model.predict(input_image)

# Post-process the predicted image if necessary
predicted_image = np.squeeze(predicted_image)  # Remove batch dimension
predicted_image *= 100  # Scale back up if you normalized to [0, 1] range

# Optionally, save the predicted image as a new GeoTIFF
output_image_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\testexample\\predictions\\predicted_tile_{tilename}_2.tif"
with rasterio.open(input_image_path) as src:
    profile = src.profile

with rasterio.open(output_image_path, 'w', **profile) as dst:
    dst.write(predicted_image.astype(rasterio.uint8), 1)  # Write the first band
print("done")
# Out:
# 1/1 [==============================] - 0s 75ms/step
# done

# %%
import os
import rasterio
import numpy as np
import tensorflow as tf

tilename = '20-2860'
input_image_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\HAGTiles\\tile_{tilename}.tif"

# Ensure 'feature_max' is correctly defined (use a known value or calculate it)
feature_max = 100  # Example value, adjust based on actual maximum height from your data

def load_and_preprocess_image(path):
    with rasterio.open(path) as src:
        image = src.read(1)
    print("Max value in image before normalization:", np.max(image))  # Debug print
    image = np.array(image).astype('float32') / feature_max
    image = np.expand_dims(image, axis=-1)
    image = np.expand_dims(image, axis=0)
    return image

input_image = load_and_preprocess_image(input_image_path)
predicted_image = model.predict(input_image)
predicted_image = np.squeeze(predicted_image)

# Debug print to check if all outputs are the same
print("Unique values in predicted output:", np.unique(predicted_image))

predicted_image *= 100

output_image_path = f"C:\\Users\\smdur\\OneDrive\\Desktop\\GLOBALPCL\\testexample\\predictions\\predicted_tile_{tilename}.tif"
with rasterio.open(input_image_path) as src:
    profile = src.profile

with rasterio.open(output_image_path, 'w', **profile) as dst:
    dst.write(predicted_image.astype(rasterio.uint8), 1)

print("Done")
# Out:
# Max value in image before normalization: 31
# 1/1 [==============================] - 0s 65ms/step
# Unique values in predicted output: [0.21187326 0.21997024 0.2237141  ... 0.34099048 0.34325328 0.3465803 ]
# Done
